# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from psypl.experiments.preconditions import BeliefBiasExperiment
from psypl.utils import get_experiments_db

# %%
db = get_experiments_db()

# %%
results = BeliefBiasExperiment().get_mongo_results(db)
results
# Out:
#             participant  mturk  trial_index  duration    age experience  \
# 0  mturk-A353XKDTUX10NC   True            0    94.828  20-29         5+
# 1  mturk-A353XKDTUX10NC   True            1   296.661  20-29         5+
# 2  mturk-A1Z27X99F97JSR   True            0    60.225  40-49        1-2
# 3  mturk-A1Z27X99F97JSR   True            1    45.172  40-49        1-2
# 4  mturk-A1BWS5AD2T4NIR   True            0   916.489  30-39         5+
# 5  mturk-A1BWS5AD2T4NIR   True            1   514.756  30-39         5+
# 6                     f  False            0    28.163  20-29         <1
# 7                     f  False            1     4.713  20-29         <1
#
#                                               answer  trial_time  \
# 0  The string email must be an email address of v...       94828
# 1  Objects which implement interface A must conta...      296661
# 2                                             /*..*/       60225
# 3                                              email       45172
# 4  objs is not null, is a List of A, has a length...      916489
# 5   email is not null and contains the character '@'      514756
# 6                 ok!\n\nNNNO O OO O O O O F U.  C K       28163
# 7                                            YEE HAW        4713
#
#                 cond             func           name  \
# 0  Content.Realistic       get_domain          email
# 1   Content.Abstract          mystery  animal_height
# 2   Content.Abstract          mystery  animal_height
# 3  Content.Realistic       get_domain          email
# 4   Content.Abstract          mystery  animal_height
# 5  Content.Realistic       get_domain          email
# 6   Content.Abstract          mystery          email
# 7  Content.Realistic  ratio_of_totals  animal_height
#
#                                              program
# 0  String get_domain(String email) {\n  String[] ...
# 1  interface A {\n  public String str();\n  publi...
# 2  interface A {\n  public String str();\n  publi...
# 3  String get_domain(String email) {\n  String[] ...
# 4  interface A {\n  public String str();\n  publi...
# 5  String get_domain(String email) {\n  String[] ...
# 6  String mystery(String s) {\n  String[] a = s.s...
# 7  interface Animal {\n  public String type();\n ...

# %%
for a in results.answer:
    print(a)
    print()
# Out:
# The string email must be an email address of valid format with a length greater than zero.
#
# Objects which implement interface A must contain either a member value str which is equal to foo or bar. If the member value str is equal to bar then the member value num must be a non-zero value.
#
# /*..*/
#
# email
#
# objs is not null, is a List of A, has a length >= 1, and at least one element of objs's str() method returns "bar" and that element's num() method returns a number greater than 0
#
# email is not null and contains the character '@'
